# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import sklearn.pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
import ydata_profiling
from ydata_profiling import ProfileReport
import dask.dataframe as dd

# %%
df = pd.read_csv('E:\Downloads\AIML Dataset.csv')

# %%
profile = ProfileReport(df, title="dataset Profiling Report", explorative=True)
profile.to_file("dataset_profiling_report.html")
# Out:
#  27%|██▋       | 3/11 [02:05<05:35, 41.90s/it]16<00:29,  4.89s/it, Describe variable: isFlaggedFraud]
# Summarize dataset:  62%|██████▎   | 10/16 [02:16<01:22, 13.69s/it, Describe variable: isFlaggedFraud]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 profile = ProfileReport(df, title="dataset Profiling Report", explorative=True)
# ----> 2 profile.to_file("dataset_profiling_report.html")
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)    496
#     497     """
# --> 498     return self.html
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)    426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\profile_report.py:270, in ProfileReport.description_set(self)
#     267 @property
#     268 def description_set(self) -> BaseDescription:
#     269     if self._description_set is None:
# --> 270         self._description_set = describe_df(
#     271             self.config,
#     272             self.df,
#     273             self.summarizer,
#     274             self.typeset,
#     275             self._sample,
#     276         )
#     277     return self._description_set
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\describe.py:89, in describe(config, df, summarizer, typeset, sample)
#      87 # Variable-specific
#      88 pbar.total += len(df.columns)
# ---> 89 series_description = get_series_descriptions(
#      90     config, df, summarizer, typeset, pbar
#      91 )
#      93 pbar.set_postfix_str("Get variable types")
#      94 pbar.total += 1
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\summary.py:62, in get_series_descriptions(config, df, summarizer, typeset, pbar)
#      54 def get_series_descriptions(
#      55     config: Settings,
#      56     df: Any,
#    (...)     59     pbar: tqdm,
#      60 ) -> dict:
#      61     if isinstance(df, pd.DataFrame):
# ---> 62         return pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      63     elif isinstance(df, sparkDataFrame):  # type: ignore
#      64         return get_series_descriptions_spark(config, df, summarizer, typeset, pbar)
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\summary_pandas.py:98, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      92     future_to_col = {
#      93         executor.submit(describe_column, name, series): name  # type:ignore
#      94         for name, series in df.items()
#      95     }
#      97     for future in tqdm(future_to_col.keys(), total=len(future_to_col)):
# ---> 98         name, description = future.result()
#      99         series_description[name] = description
#     101 return sort_column_names(series_description, config.sort)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\summary_pandas.py:81, in pandas_get_series_descriptions.<locals>.describe_column(name, series)
#      79 """Process a single series to get the column description."""
#      80 pbar.set_postfix_str(f"Describe variable: {name}")
# ---> 81 description = pandas_describe_1d(config, series, summarizer, typeset)
#      82 pbar.update()
#      83 return name, description
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\summary_pandas.py:63, in pandas_describe_1d(config, series, summarizer, typeset)
#      60     vtype = typeset.detect_type(series)
#      62 typeset.type_schema[series.name] = vtype  # type:ignore
# ---> 63 summary = summarizer.summarize(config, series, dtype=vtype)
#      64 # Cast type is only used on unsupported columns rendering pipeline
#      65 # to indicate the correct variable type when inference is not possible
#      66 summary["cast_type"] = cast_type
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\summarizer.py:50, in BaseSummarizer.summarize(self, config, series, dtype)
#      46 def summarize(
#      47     self, config: Settings, series: pd.Series, dtype: Type[VisionsBaseType]
#      48 ) -> dict:
#      49     """Generates the summary for a given series"""
# ---> 50     return self.handle(str(dtype), config, series, {"type": str(dtype)})
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\handler.py:59, in Handler.handle(self, dtype, *args, **kwargs)
#      57 funcs = self.mapping.get(dtype, [])
#      58 op = compose(funcs)
# ---> 59 summary = op(*args)[-1]
#      60 return summary
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\handler.py:21, in compose.<locals>.composed_function(*args)
#      19 result = args  # Start with the input arguments
#      20 for func in functions:
# ---> 21     result = func(*result) if isinstance(result, tuple) else func(result)
#      22 return result
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\summary_algorithms.py:72, in series_hashable.<locals>.inner(config, series, summary)
#      70 if not summary["hashable"]:
#      71     return config, series, summary
# ---> 72 return fn(config, series, summary)
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\summary_algorithms.py:89, in series_handle_nulls.<locals>.inner(config, series, summary)
#      86 if series.hasnans:
#      87     series = series.dropna()
# ---> 89 return fn(config, series, summary)
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\describe_text_pandas.py:57, in pandas_describe_text_1d(config, series, summary)
#      46     summary.update(
#      47         histogram_compute(
#      48             config,
#    (...)     53         )
#      54     )
#      56 if config.vars.text.characters:
# ---> 57     summary.update(unicode_summary_vc(value_counts))
#      59 if config.vars.text.words:
#      60     summary.update(word_summary_vc(value_counts, config.vars.cat.stop_words))
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\describe_categorical_pandas.py:77, in unicode_summary_vc(vc)
#      74     script = char_handler
#      76 # Unicode Character Summaries (category and script name)
# ---> 77 character_counts = get_character_counts_vc(vc)
#      79 character_counts_series = character_counts
#      80 summary = {
#      81     "n_characters_distinct": len(character_counts_series),
#      82     "n_characters": np.sum(character_counts_series.values),
#      83     "character_counts": character_counts_series,
#      84 }
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\ydata_profiling\model\pandas\describe_categorical_pandas.py:25, in get_character_counts_vc(vc)
#      23 series = pd.Series(vc.index, index=vc, dtype=object)
#      24 characters = series[series != ""].apply(list)
# ---> 25 characters = characters.explode()
#      27 counts = pd.Series(characters.index, index=characters).dropna()
#      28 if len(counts) > 0:
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\pandas\core\series.py:4573, in Series.explode(self, ignore_index)
#    4570 else:
#    4571     index = self.index.repeat(counts)
# -> 4573 return self._constructor(values, index=index, name=self.name, copy=False)
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\pandas\core\construction.py:604, in sanitize_array(data, index, dtype, copy, allow_2d)
#     602 subarr = data
#     603 if data.dtype == object:
# --> 604     subarr = maybe_infer_to_datetimelike(data)
#     605     if object_index and using_string_dtype() and is_string_dtype(subarr):
#     606         # Avoid inference when string option is set
#     607         subarr = data
#
# File e:\OneDrive\Documents\coding\MLInternship\myenv\Lib\site-packages\pandas\core\dtypes\cast.py:1198, in maybe_infer_to_datetimelike(value, convert_to_nullable_dtype)
#    1193     return value
#    1195 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1196 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1197 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1198 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1199     value,
#    1200     # Here we do not convert numeric dtypes, as if we wanted that,
#    1201     #  numpy would have done it for us.
#    1202     convert_numeric=False,
#    1203     convert_non_numeric=True,
#    1204     convert_to_nullable_dtype=convert_to_nullable_dtype,
#    1205     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1206 )
#
# File pandas/_libs/lib.pyx:2556, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 1016. MiB for an array with shape (66597511,) and data type complex128
